# %%
import numpy as np
from tensorflow import keras

# %%
def generate_time_series(batch_size, n_steps): 
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1) 
    time = np.linspace(0, 1, n_steps) 
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10)) # wave 1 
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # + wave 2 
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5) # + noise 
    return series[..., np.newaxis].astype(np.float32)

# %%
n_steps = 50 
series = generate_time_series(10000, n_steps + 1) 
X_train, y_train = series[:7000, :n_steps], series[:7000, -1] 
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1] 
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %%
y_pred = X_valid[:, -1]
np.mean(keras.losses.MeanSquaredError(y_valid, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 y_pred = X_valid[:, -1]
# ----> 2 np.mean(keras.losses.MeanSquaredError(y_valid, y_pred))
#
# File /opt/miniconda3/envs/tf_env/lib/python3.10/site-packages/keras/src/losses/losses.py:84, in MeanSquaredError.__init__(self, reduction, name, dtype)
#      78 def __init__(
#      79     self,
#      80     reduction="sum_over_batch_size",
#      81     name="mean_squared_error",
#      82     dtype=None,
#      83 ):
# ---> 84     super().__init__(
#      85         mean_squared_error, name=name, reduction=reduction, dtype=dtype
#      86     )
#
# File /opt/miniconda3/envs/tf_env/lib/python3.10/site-packages/keras/src/losses/losses.py:23, in LossFunctionWrapper.__init__(self, fn, reduction, name, dtype, **kwargs)
#      15 def __init__(
#      16     self,
#      17     fn,
#    (...)
# ...

# %%
model = keras.models.Sequential([
    keras.layers.SimpleRNN(1, input_shape=[None, 1],unroll=True)
    
    ])

model.compile(loss="mse", optimizer="adam")
model.fit(X_train,y_train,epochs = 20,
          validation_data = (X_valid,y_valid))
# Out:
# Epoch 1/20
# 2026-03-10 17:04:26.797702: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.9174 - val_loss: 0.8505
# Epoch 2/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.7218 - val_loss: 0.7044
# Epoch 3/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.5553 - val_loss: 0.4606
# Epoch 4/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.4078 - val_loss: 0.3956
# Epoch 5/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.3458 - val_loss: 0.3284
# Epoch 6/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.2903 - val_loss: 0.2826
# Epoch 7/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.2517 - val_loss: 0.2436
# Epoch 8/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.2158 - val_loss: 0.2080
# Epoch 9/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.1813 - val_loss: 0.1737
# Epoch 10/20
# ...

# %%
# 让模型去做题，并算出均方误差 (MSE)
loss = model.evaluate(X_test, y_test)
print(f"RNN 测试集最终误差: {loss:.5f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1353
# RNN 测试集最终误差: 0.13527

# %%
import tensorflow as tf
from tensorflow import keras

model_lstm = keras.models.Sequential([
    keras.layers.LSTM(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.LSTM(20),
    keras.layers.Dense(1)
])

model_lstm.compile(loss="mse", optimizer="adam")
model_lstm.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 2026-03-12 21:49:16.846490: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0476 - val_loss: 0.0235
# Epoch 2/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0186 - val_loss: 0.0132
# Epoch 3/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0111 - val_loss: 0.0075
# Epoch 4/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0064 - val_loss: 0.0060
# Epoch 5/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0044 - val_loss: 0.0038
# Epoch 6/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 7/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 8/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 9/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 10/20
# ...

# %%
loss = model_lstm.evaluate(X_test, y_test)
print(f"LSTM 战车最终误差: {loss:.5f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026
# LSTM 战车最终误差: 0.00259

# %%
import tensorflow as tf
from tensorflow import keras

model_gru = keras.models.Sequential([
    keras.layers.GRU(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.GRU(20),
    keras.layers.Dense(1)
])

model_gru.compile(loss="mse", optimizer="adam")
model_gru.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0403 - val_loss: 0.0166
# Epoch 2/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0086 - val_loss: 0.0057
# Epoch 3/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 4/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0045 - val_loss: 0.0043
# Epoch 5/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 6/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 7/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 8/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 9/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 10/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 11/20
# ...

# %%
loss = model_gru.evaluate(X_test, y_test)
print(f"LSTM 战车最终误差: {loss:.5f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030
# LSTM 战车最终误差: 0.00303
