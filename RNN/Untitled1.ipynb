# %%
from datetime import date
min_date = date(1000, 1, 1).toordinal()
max_date = date(9999,12,31).toordinal()
print(min_date,max_date)
# Out:
# 364878 3652059

# %%
min_date = date.fromordinal(min_date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 min_date = date.fromordinal(min_date)
#       2 print(min_date)
#
# TypeError: 'datetime.date' object cannot be interpreted as an integer

# %%
print(min_date)
# Out:
# 1000-01-01

# %%
MONTHS = ["January", "February", "March", "April", "May", "June",
          "July", "August", "September", "October", "November", "December"]
INPUT_CHARS = "".join(set("".join(MONTHS) + "0123456789, -/"))

# %%
INPUT_CHARS
# Out:
# 'iF0y9t,o13nMresAm-ac4/luS Nh6v8p72bOgDJ5'
