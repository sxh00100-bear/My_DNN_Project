# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

print("✅ 本地AI环境测试成功！")
print("pandas版本:", pd.__version__)
print("numpy版本:", np.__version__)

# 测试一个小功能：创建一个简单的DataFrame
df_test = pd.DataFrame({'A': [1, 2, 3], 'B': ['a', 'b', 'c']})
print("\n测试DataFrame:")
print(df_test)
# Out:
# ✅ 本地AI环境测试成功！
# pandas版本: 2.3.3
# numpy版本: 2.3.5
#
# 测试DataFrame:
#    A  B
# 0  1  a
# 1  2  b
# 2  3  c

# %%
#一个保存图片的函数，路径是同一目录下，创建一个image的文件夹，存在里边，图片格式png，像素300，
def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
